# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/connected-bsamadi/colab-notebooks/blob/master/neural_complete.ipynb)

# %% [markdown]
# # Code Recommendation Demo
# In [neural_complete](https://github.com/kootenpv/neural_complete), a neural network was trained to help writing neural network code using autocomplete.

# %%
# Installing required packages
# !pip install just > /dev/null

# %%
# Clone the neural_complete repository
# !git clone https://github.com/kootenpv/neural_complete > /dev/null
# Out:
# Cloning into 'neural_complete'...
# remote: Counting objects: 273, done.
# remote: Total 273 (delta 0), reused 0 (delta 0), pack-reused 273
# Receiving objects: 100% (273/273), 3.49 MiB | 26.70 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
import sys
sys.path.insert(0,'./neural_complete/backend')

# %%
import just
from encoder_decoder import TextEncoderDecoder, text_tokenize
from model import LSTMBase
# Out:
# Using TensorFlow backend.

# %%
import neural_complete as nc

# %%
data = list(just.multi_read("neural_complete/backend/data/**/*.py").values())

# %%
len(data)
# Out:
# 24

# %%
ted = TextEncoderDecoder(data, tokenize=text_tokenize, untokenize="".join, padding=" ", min_count=1, maxlen=20)
# Out:
# unique question tokens: 359
# unique answer tokens: 193
# number of QA pairs: 1418

# %%
nc.train(ted, "neural_token")
# Out:
# Building model...
#
# --------------------------------------------------
# Iteration 0
# /usr/local/lib/python3.6/dist-packages/keras/models.py:981: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/3
# 1418/1418 [==============================] - 2s 1ms/step - loss: 5.1524
# Epoch 2/3
# 1418/1418 [==============================] - 1s 935us/step - loss: 4.0918
# Epoch 3/3
# 1418/1418 [==============================] - 1s 927us/step - loss: 3.8771
# ----- Generating with seed:
#
#  from keras.layers import
#
#
# --PREDICTION--
#
#
# --------- diversity 0.2 -------
# ......
# ...........
# .
# --------- diversity 0.5 -------
# .
#
# ...()
# ).(Sequential......[
# --------- diversity 1 -------
#
# .
# ,.
# .import.layers .U_f
# (.add
#
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/3
# 1418/1418 [==============================] - 1s 928us/step - loss: 4.2346
# ...

# %%
model=nc.get_model("neural_token")

# %%
nc.neural_complete(model, "from keras import ", [0.2, 0.5, 1])
# Out:
# ['from keras import ',
#  'from keras import SimpleRNN',
#  'from keras import relu moves']
